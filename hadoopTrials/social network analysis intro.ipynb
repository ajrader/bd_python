# %% [markdown]
# # SNA using networkx Katy Chuang Tutorial from March 2013 PyData

# %%
import networkx

# %%
g = networkx.Graph() # create undirected graph object

# %%
g.add_edge(1,2)
g.add_edge(3,1)
g.add_node(4)

# %%
print g.number_of_nodes()
# Out:
# 4

# %%
print g.nodes()
# Out:
# [1, 2, 3, 4]

# %%
print g.number_of_edges()
# Out:
# 2

# %%
print g.edges()
# Out:
# [(1, 2), (1, 3)]

# %%
g = networkx.DiGraph() # directed

# %%
networkx.__version__
# Out:
# '1.8.1'

# %%
g.degree()
# Out:
# {}

# %%
pwd
# Out:
# u'C:\\Users\\KESJ\\code\\python\\ipythonNotebooks\\hadoopTrials'

# %%
cd 'testing/'
# Out:
# C:\Users\KESJ\code\python\ipythonNotebooks\hadoopTrials\testing

# %%
# %run virus.py
